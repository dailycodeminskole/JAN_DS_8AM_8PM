# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('gapminder_full.csv')

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.loc[0]
# Out:
# country       Afghanistan
# year                 1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap        779.445314
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# country       Afghanistan
# year                 1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap        779.445314
# Name: 0, dtype: object

# %%
df.iloc[0:5]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.iloc[1700:]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.iloc[::1000]
# Out:
#           country  year  population continent  life_exp      gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801   779.445314
# 1000     Mongolia  1972     1320500      Asia    53.754  1421.741975

# %%
df.iloc[::-1]
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# ...           ...   ...         ...       ...       ...         ...
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
#
# [1704 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
d = {'country':'India', 'year':2020, 'population':1000000, 'continent':'Asia', 'life_exp':44.11, 'gdp_cap':101.1}

# %%
df.append(d,ignore_index=True)
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_8600\1429863610.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(d,ignore_index=True)
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# ...

# %%
df.iloc[1703]
# Out:
# country         Zimbabwe
# year                2007
# population      12311143
# continent         Africa
# life_exp          43.487
# gdp_cap       469.709298
# Name: 1703, dtype: object

# %%
df.loc[1704] =  pd.Series(d)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2020     1000000      Asia    44.110  101.100000
#
# [1705 rows x 6 columns]

# %%
d1 = {'country':'India', 'year':2020, 'population':1000000, 'continent':'Asia', 'life_exp':44.11, 'gdp_cap':101.1}

# %%
df.loc[1705]= pd.Series(d1)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2020     1000000      Asia    44.110  101.100000
# 1705        India  2020     1000000      Asia    44.110  101.100000
#
# [1706 rows x 6 columns]

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1701    False
# 1702    False
# 1703    False
# 1704    False
# 1705     True
# Length: 1706, dtype: bool

# %%
df[df.duplicated()]
# Out:
#      country  year  population continent  life_exp  gdp_cap
# 1705   India  2020     1000000      Asia     44.11    101.1

# %%
df.drop_duplicates(keep='last')
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1705        India  2020     1000000      Asia    44.110  101.100000
#
# [1705 rows x 6 columns]

# %%
df.drop(1705,axis=0)
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2020     1000000      Asia    44.110  101.100000
#
# [1705 rows x 6 columns]

# %%
df.drop(2,axis=0)
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2020     1000000      Asia    44.110  101.100000
# 1705        India  2020     1000000      Asia    44.110  101.100000
#
# [1705 rows x 6 columns]

# %% [markdown]
# # working with rows and columns

# %%
# using loc and iloc

# %%
df.iloc[0:5,0:3]
# Out:
#        country  year  population
# 0  Afghanistan  1952     8425333
# 1  Afghanistan  1957     9240934
# 2  Afghanistan  1962    10267083
# 3  Afghanistan  1967    11537966
# 4  Afghanistan  1972    13079460

# %%
df.loc[0:5,'country':'population'] #last value is included in loc while slicing
# Out:
#        country  year  population
# 0  Afghanistan  1952     8425333
# 1  Afghanistan  1957     9240934
# 2  Afghanistan  1962    10267083
# 3  Afghanistan  1967    11537966
# 4  Afghanistan  1972    13079460
# 5  Afghanistan  1977    14880372

# %% [markdown]
# # Operations in Pandas

# %%
df.describe()
# Out:
#               year    population     life_exp        gdp_cap
# count  1706.000000  1.706000e+03  1706.000000    1706.000000
# mean   1979.547479  2.956768e+07    59.456427    7206.986838
# std      17.310798  1.061001e+08    12.920237    9854.680509
# min    1952.000000  6.001100e+04    23.599000     101.100000
# 25%    1967.000000  2.783061e+06    48.135000    1198.017212
# 50%    1982.000000  7.021053e+06    60.601000    3529.585686
# 75%    1997.000000  1.956929e+07    70.842750    9322.285886
# max    2020.000000  1.318683e+09    82.603000  113523.132900

# %%
df.describe(include='object')
# Out:
#        country continent
# count     1706      1706
# unique     142         5
# top      India    Africa
# freq        14       624

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
type(df['life_exp'])
# Out:
# pandas.core.series.Series

# %%
df['life_exp'].mean()
# Out:
# 59.45642712778425

# %%
df['life_exp'].sum()
# Out:
# 101432.66467999999

# %%
df['life_exp'].count()
# Out:
# 1706

# %%
df['life_exp'].min()
# Out:
# 23.599

# %%
df['life_exp'].max()
# Out:
# 82.603
