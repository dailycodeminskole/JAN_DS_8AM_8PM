# %%
# logical 
# any
# all
arr1 = np.array([1,0,0,0,0])
np.any(arr1)

arr2 = np.array([1,1,0,1,1])
np.all(arr2)
# Out:
# False

# %%
# importing imp modules
import numpy as np
import pandas as pd

# %% [markdown]
# # importing the data and saving the dataframes in a variable

# %%
data = pd.read_csv('matches.csv')

# %% [markdown]
# # understanding the fields in dataframes

# %%
# basic attributes and functions

# %%
data.shape
# Out:
# (636, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.tail()
# Out:
#       id  season       city        date                team1  \
# 631  632    2016     Raipur  2016-05-22     Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24        Gujarat Lions
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
data.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
data.describe(include='all')
# Out:
#                 id       season    city        date           team1  \
# count   636.000000   636.000000     629         636             636
# unique         NaN          NaN      30         450              14
# top            NaN          NaN  Mumbai  2012-04-19  Mumbai Indians
# freq           NaN          NaN      85           2              82
# mean    318.500000  2012.490566     NaN         NaN             NaN
# std     183.741666     2.773026     NaN         NaN             NaN
# min       1.000000  2008.000000     NaN         NaN             NaN
# 25%     159.750000  2010.000000     NaN         NaN             NaN
# 50%     318.500000  2012.000000     NaN         NaN             NaN
# 75%     477.250000  2015.000000     NaN         NaN             NaN
# max     636.000000  2017.000000     NaN         NaN             NaN
#
#                    team2     toss_winner toss_decision  result  dl_applied  \
# ...

# %% [markdown]
# # getting rows and columns

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
data['winner']
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
type(data['winner'])
# Out:
# pandas.core.series.Series

# %%
data[['winner','team1','team2']]
# Out:
#                           winner                        team1  \
# 0            Sunrisers Hyderabad          Sunrisers Hyderabad
# 1         Rising Pune Supergiant               Mumbai Indians
# 2          Kolkata Knight Riders                Gujarat Lions
# 3                Kings XI Punjab       Rising Pune Supergiant
# 4    Royal Challengers Bangalore  Royal Challengers Bangalore
# ..                           ...                          ...
# 631  Royal Challengers Bangalore             Delhi Daredevils
# 632  Royal Challengers Bangalore                Gujarat Lions
# 633          Sunrisers Hyderabad          Sunrisers Hyderabad
# 634          Sunrisers Hyderabad                Gujarat Lions
# 635          Sunrisers Hyderabad          Sunrisers Hyderabad
#
#                            team2
# 0    Royal Challengers Bangalore
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4               Delhi Daredevils
# ...

# %%
type(data[['winner','team1','team2']])
# Out:
# pandas.core.frame.DataFrame

# %%
# getting data from rows

# %%
data.iloc[0]
# Out:
# id                                                         1
# season                                                  2017
# city                                               Hyderabad
# date                                              2017-04-05
# team1                                    Sunrisers Hyderabad
# team2                            Royal Challengers Bangalore
# toss_winner                      Royal Challengers Bangalore
# toss_decision                                          field
# result                                                normal
# dl_applied                                                 0
# winner                                   Sunrisers Hyderabad
# win_by_runs                                               35
# win_by_wickets                                             0
# player_of_match                                 Yuvraj Singh
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %%
type(data.iloc[0])
# Out:
# pandas.core.series.Series

# %%
data.iloc[0:10:2] #slicing with jump values
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 8   9    2017       Pune  2017-04-11             Delhi Daredevils
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
# 6               Mumbai Indians               Mumbai Indians         field
# 8       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.iloc[[10,99,199]] #particular rows only
# Out:
#       id  season     city        date             team1  \
# 10    11    2017  Kolkata  2017-04-13   Kings XI Punjab
# 99   100    2008    Delhi  2008-05-17  Delhi Daredevils
# 199  200    2010    Delhi  2010-03-29  Delhi Daredevils
#
#                      team2            toss_winner toss_decision  result  \
# 10   Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 99         Kings XI Punjab       Delhi Daredevils           bat  normal
# 199  Kolkata Knight Riders       Delhi Daredevils           bat  normal
#
#      dl_applied                 winner  win_by_runs  win_by_wickets  \
# 10            0  Kolkata Knight Riders            0               8
# 99            1        Kings XI Punjab            6               0
# 199           0       Delhi Daredevils           40               0
#
#       player_of_match             venue         umpire1      umpire2  umpire3
# 10          SP Narine      Eden Gardens      A Deshmukh     NJ Llong      NaN
# ...

# %%
# winner , team 1 and 2

# data.iloc[rows , columns]
data.iloc[:,[10,4,5]]
# Out:
#                           winner                        team1  \
# 0            Sunrisers Hyderabad          Sunrisers Hyderabad
# 1         Rising Pune Supergiant               Mumbai Indians
# 2          Kolkata Knight Riders                Gujarat Lions
# 3                Kings XI Punjab       Rising Pune Supergiant
# 4    Royal Challengers Bangalore  Royal Challengers Bangalore
# ..                           ...                          ...
# 631  Royal Challengers Bangalore             Delhi Daredevils
# 632  Royal Challengers Bangalore                Gujarat Lions
# 633          Sunrisers Hyderabad          Sunrisers Hyderabad
# 634          Sunrisers Hyderabad                Gujarat Lions
# 635          Sunrisers Hyderabad          Sunrisers Hyderabad
#
#                            team2
# 0    Royal Challengers Bangalore
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4               Delhi Daredevils
# ...

# %%
data.loc[:,['winner','team1','team2']]
# Out:
#                           winner                        team1  \
# 0            Sunrisers Hyderabad          Sunrisers Hyderabad
# 1         Rising Pune Supergiant               Mumbai Indians
# 2          Kolkata Knight Riders                Gujarat Lions
# 3                Kings XI Punjab       Rising Pune Supergiant
# 4    Royal Challengers Bangalore  Royal Challengers Bangalore
# ..                           ...                          ...
# 631  Royal Challengers Bangalore             Delhi Daredevils
# 632  Royal Challengers Bangalore                Gujarat Lions
# 633          Sunrisers Hyderabad          Sunrisers Hyderabad
# 634          Sunrisers Hyderabad                Gujarat Lions
# 635          Sunrisers Hyderabad          Sunrisers Hyderabad
#
#                            team2
# 0    Royal Challengers Bangalore
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4               Delhi Daredevils
# ...

# %% [markdown]
# # data filtering using fancy indexing

# %%
# matches only in hyderabad

# %%
mask1 = data['city'] == 'Hyderabad'

# %%
mask1
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 631    False
# 632    False
# 633    False
# 634    False
# 635    False
# Name: city, Length: 636, dtype: bool

# %%
data[mask1]
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 5      6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 18    19    2017  Hyderabad  2017-04-17          Sunrisers Hyderabad
# 20    21    2017  Hyderabad  2017-04-19          Sunrisers Hyderabad
# 35    36    2017  Hyderabad  2017-04-30          Sunrisers Hyderabad
# 42    43    2017  Hyderabad  2017-05-06       Rising Pune Supergiant
# 46    47    2017  Hyderabad  2017-05-08               Mumbai Indians
# 58    59    2017  Hyderabad  2017-05-21               Mumbai Indians
# 65    66    2008  Hyderabad  2008-04-22              Deccan Chargers
# 67    68    2008  Hyderabad  2008-04-24              Deccan Chargers
# 76    77    2008  Hyderabad  2008-05-01              Deccan Chargers
# 79    80    2008  Hyderabad  2008-05-25              Deccan Chargers
# 91    92    2008  Hyderabad  2008-05-11        Kolkata Knight Riders
# ...

# %%
data[mask1].shape
# Out:
# (49, 18)

# %%
# creating a functio to filter thhe data by city as an argumnet

# %%
def match_city(city):
    mask1 = data['city'] == city
    return data[mask1].shape[0]
match_city('Pune') 
match_city('Bangalore')
match_city('Mumbai')
# Out:
# 85

# %%
mask = data['team1']=='Delhi Daredevils'

# %%
mask1 = data['season']>2010

# %%
data[mask1 & mask].shape
# Out:
# (44, 18)

# %%
data[mask]
# Out:
#       id  season           city        date             team1  \
# 8      9    2017           Pune  2017-04-11  Delhi Daredevils
# 14    15    2017          Delhi  2017-04-15  Delhi Daredevils
# 17    18    2017          Delhi  2017-04-17  Delhi Daredevils
# 30    31    2017        Kolkata  2017-04-28  Delhi Daredevils
# 34    35    2017     Chandigarh  2017-04-30  Delhi Daredevils
# ..   ...     ...            ...         ...               ...
# 592  593    2016          Delhi  2016-04-23  Delhi Daredevils
# 601  602    2016          Delhi  2016-04-30  Delhi Daredevils
# 608  609    2016          Delhi  2016-05-05  Delhi Daredevils
# 624  625    2016  Visakhapatnam  2016-05-17  Delhi Daredevils
# 631  632    2016         Raipur  2016-05-22  Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# 8         Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
# adding more conditions

# %%
mask2 = data['date'] > '2010-01-01'

# %%
mask2
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 631    True
# 632    True
# 633    True
# 634    True
# 635    True
# Name: date, Length: 636, dtype: bool

# %%
data[mask1 & mask2]
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 5      6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 18    19    2017  Hyderabad  2017-04-17          Sunrisers Hyderabad
# 20    21    2017  Hyderabad  2017-04-19          Sunrisers Hyderabad
# 35    36    2017  Hyderabad  2017-04-30          Sunrisers Hyderabad
# 42    43    2017  Hyderabad  2017-05-06       Rising Pune Supergiant
# 46    47    2017  Hyderabad  2017-05-08               Mumbai Indians
# 58    59    2017  Hyderabad  2017-05-21               Mumbai Indians
# 235  236    2011  Hyderabad  2011-04-09              Deccan Chargers
# 244  245    2011  Hyderabad  2011-04-14              Deccan Chargers
# 248  249    2011  Hyderabad  2011-04-16              Deccan Chargers
# 259  260    2011  Hyderabad  2011-04-24               Mumbai Indians
# 274  275    2011  Hyderabad  2011-05-03        Kolkata Knight Riders
# ...

# %%
data[mask1 & mask2].shape
# Out:
# (42, 18)

# %%
match_city('Hyderabad')
# Out:
# 49

# %% [markdown]
# # value counts
# # freq counts over a categorical data

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data['winner'].value_counts()
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %% [markdown]
# # plotting the data in a chart

# %%
# plotting for better understanding
import matplotlib.pyplot as plt

# %%
data['winner'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['winner'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
data['winner'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='winner'>

# %%
# toss decision

# %%
data['toss_decision'].value_counts()
# Out:
# field    363
# bat      273
# Name: toss_decision, dtype: int64

# %%
data['toss_decision'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['toss_decision'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='toss_decision'>

# %%
data['win_by_runs'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.head(10)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8   9    2017       Pune  2017-04-11             Delhi Daredevils
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
# total number of matches playesd by each team

# %%
data['team1'].value_counts()
# Out:
# Mumbai Indians                 82
# Kings XI Punjab                77
# Chennai Super Kings            77
# Royal Challengers Bangalore    70
# Kolkata Knight Riders          68
# Delhi Daredevils               63
# Rajasthan Royals               54
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  14
# Rising Pune Supergiant          8
# Kochi Tuskers Kerala            7
# Rising Pune Supergiants         7
# Name: team1, dtype: int64

# %%
data['team2'].value_counts()
# Out:
# Delhi Daredevils               84
# Royal Challengers Bangalore    82
# Kolkata Knight Riders          80
# Mumbai Indians                 75
# Kings XI Punjab                71
# Rajasthan Royals               64
# Chennai Super Kings            54
# Deccan Chargers                32
# Sunrisers Hyderabad            30
# Pune Warriors                  26
# Gujarat Lions                  16
# Rising Pune Supergiant          8
# Kochi Tuskers Kerala            7
# Rising Pune Supergiants         7
# Name: team2, dtype: int64

# %%
type(data['team2'].value_counts())
# Out:
# pandas.core.series.Series

# %%
data['team1'].value_counts() +  data['team2'].value_counts()
# Out:
# Chennai Super Kings            131
# Deccan Chargers                 75
# Delhi Daredevils               147
# Gujarat Lions                   30
# Kings XI Punjab                148
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          148
# Mumbai Indians                 157
# Pune Warriors                   46
# Rajasthan Royals               118
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    152
# Sunrisers Hyderabad             76
# dtype: int64

# %% [markdown]
# # sorting data in a series or dataframes

# %%
(data['team1'].value_counts() +  data['team2'].value_counts()).sort_values()
(data['team1'].value_counts() +  data['team2'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 157
# Royal Challengers Bangalore    152
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Delhi Daredevils               147
# Chennai Super Kings            131
# Rajasthan Royals               118
# Sunrisers Hyderabad             76
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# dtype: int64

# %%
# based on city

# %%
data.sort_values(['city']).head(15)
# Out:
#       id  season       city        date                        team1  \
# 460  461    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 459  460    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# 457  458    2014  Abu Dhabi  2014-04-16        Kolkata Knight Riders
# 475  476    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
# 539  540    2015  Ahmedabad  2015-04-24             Rajasthan Royals
# 481  482    2014  Ahmedabad  2014-05-05             Rajasthan Royals
# 486  487    2014  Ahmedabad  2014-05-08          Sunrisers Hyderabad
# 194  195    2010  Ahmedabad  2010-03-26              Deccan Chargers
# 535  536    2015  Ahmedabad  2015-04-21             Rajasthan Royals
# 197  198    2010  Ahmedabad  2010-03-28             Rajasthan Royals
# ...

# %%
# sorting by two parameters

# %%
data.sort_values(['city','date']).head(15)
# Out:
#       id  season       city        date                        team1  \
# 457  458    2014  Abu Dhabi  2014-04-16        Kolkata Knight Riders
# 459  460    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# 460  461    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# 475  476    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
# 179  180    2010  Ahmedabad  2010-03-15             Rajasthan Royals
# 186  187    2010  Ahmedabad  2010-03-20             Rajasthan Royals
# 194  195    2010  Ahmedabad  2010-03-26              Deccan Chargers
# 197  198    2010  Ahmedabad  2010-03-28             Rajasthan Royals
# 481  482    2014  Ahmedabad  2014-05-05             Rajasthan Royals
# 486  487    2014  Ahmedabad  2014-05-08          Sunrisers Hyderabad
# ...

# %%
data.sort_values(['city','date'],ascending=[True,False]).head(15)
# Out:
#       id  season       city        date                        team1  \
# 475  476    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 459  460    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# 460  461    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 457  458    2014  Abu Dhabi  2014-04-16        Kolkata Knight Riders
# 539  540    2015  Ahmedabad  2015-04-24             Rajasthan Royals
# 535  536    2015  Ahmedabad  2015-04-21             Rajasthan Royals
# 532  533    2015  Ahmedabad  2015-04-19          Chennai Super Kings
# 525  526    2015  Ahmedabad  2015-04-14               Mumbai Indians
# 500  501    2014  Ahmedabad  2014-05-19               Mumbai Indians
# 497  498    2014  Ahmedabad  2014-05-15             Rajasthan Royals
# ...

# %%
data['city'] = pd.
# Out:
# 0      Hyderabad
# 1           Pune
# 2         Rajkot
# 3         Indore
# 4      Bangalore
#          ...
# 631       Raipur
# 632    Bangalore
# 633        Delhi
# 634        Delhi
# 635    Bangalore
# Name: city, Length: 636, dtype: object

# %% [markdown]
# # drop_duplicates

# %%
# exporting the selected dataframes to a csv file

# %%
s = data[['city','team1']]

# %%
s.to_csv('city_team.csv')

# %%
# dropping te duplicate values

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.drop_duplicates(subset=['city'])
# Out:
#       id  season            city        date                        team1  \
# 0      1    2017       Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017            Pune  2017-04-06               Mumbai Indians
# 2      3    2017          Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017          Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017       Bangalore  2017-04-08  Royal Challengers Bangalore
# 6      7    2017          Mumbai  2017-04-09        Kolkata Knight Riders
# 10    11    2017         Kolkata  2017-04-13              Kings XI Punjab
# 14    15    2017           Delhi  2017-04-15             Delhi Daredevils
# 31    32    2017      Chandigarh  2017-04-28          Sunrisers Hyderabad
# 48    49    2017          Kanpur  2017-05-10                Gujarat Lions
# 64    65    2008          Jaipur  2008-04-21              Kings XI Punjab
# 66    67    2008         Chennai  2008-04-23          Chennai Super Kings
# ...

# %%
(data.drop_duplicates(subset=['city'])).shape
# Out:
# (31, 18)

# %%
# with two values

# %%
data.drop_duplicates(subset=['city','season'])
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...            ...         ...                          ...
# 583  584    2016      Hyderabad  2016-04-16          Sunrisers Hyderabad
# 591  592    2016           Pune  2016-04-22  Royal Challengers Bangalore
# 612  613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 626  627    2016         Kanpur  2016-05-19        Kolkata Knight Riders
# 627  628    2016         Raipur  2016-05-20          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
# findin the IPL winner of every season

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.drop_duplicates('season').sort_values('season')
# Out:
#       id  season       city        date                  team1  \
# 59    60    2008  Bangalore  2008-04-18  Kolkata Knight Riders
# 117  118    2009  Cape Town  2009-04-18         Mumbai Indians
# 174  175    2010     Mumbai  2010-03-12  Kolkata Knight Riders
# 234  235    2011    Chennai  2011-04-08    Chennai Super Kings
# 307  308    2012    Chennai  2012-04-04    Chennai Super Kings
# 381  382    2013    Kolkata  2013-04-03       Delhi Daredevils
# 457  458    2014  Abu Dhabi  2014-04-16  Kolkata Knight Riders
# 517  518    2015    Kolkata  2015-04-08         Mumbai Indians
# 576  577    2016     Mumbai  2016-04-09         Mumbai Indians
# 0      1    2017  Hyderabad  2017-04-05    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 59   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 117          Chennai Super Kings          Chennai Super Kings         field
# ...

# %%
len(data.drop_duplicates('season'))
# Out:
# 10

# %%
#  to find the last day in the sorted season value
data.drop_duplicates('season',keep='last')
# Out:
#       id  season          city        date                team1  \
# 58    59    2017     Hyderabad  2017-05-21       Mumbai Indians
# 116  117    2008        Mumbai  2008-06-01  Chennai Super Kings
# 173  174    2009  Johannesburg  2009-05-24      Deccan Chargers
# 233  234    2010        Mumbai  2010-04-25  Chennai Super Kings
# 306  307    2011       Chennai  2011-05-28  Chennai Super Kings
# 380  381    2012       Chennai  2012-05-27  Chennai Super Kings
# 456  457    2013       Kolkata  2013-05-26       Mumbai Indians
# 516  517    2014     Bangalore  2014-06-01      Kings XI Punjab
# 575  576    2015       Kolkata  2015-05-24       Mumbai Indians
# 635  636    2016     Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 58        Rising Pune Supergiant               Mumbai Indians           bat
# 116             Rajasthan Royals             Rajasthan Royals         field
# ...

# %%
# sorting the values

data.drop_duplicates('season',keep='last')[['season','winner','date']].sort_values('season')
# Out:
#      season                 winner        date
# 116    2008       Rajasthan Royals  2008-06-01
# 173    2009        Deccan Chargers  2009-05-24
# 233    2010    Chennai Super Kings  2010-04-25
# 306    2011    Chennai Super Kings  2011-05-28
# 380    2012  Kolkata Knight Riders  2012-05-27
# 456    2013         Mumbai Indians  2013-05-26
# 516    2014  Kolkata Knight Riders  2014-06-01
# 575    2015         Mumbai Indians  2015-05-24
# 635    2016    Sunrisers Hyderabad  2016-05-29
# 58     2017         Mumbai Indians  2017-05-21
